# %% [markdown]
# # Import Libraries & Create API Object

# %%
# Twitter Analysis
# Patrick Kelly
# patkelly92@gmail.com
# https://www.linkedin.com/in/patrick--kelly/
# importing libraries and adding Authentication Information

import tweepy
import pandas as pd
import json
import time
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.corpus import stopwords
english_stops = stopwords.words('english')
english_stops.append('http')

consumer_key = "xxxxxxxxxx"
consumer_secret = "xxxxxxxxxx"
access_token = "xxxxxxxxxx"
access_token_secret = "xxxxxxxxxx"

# Creating the authentication object
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
# Setting your access token and secret
auth.set_access_token(access_token, access_token_secret)
# Creating the API object while passing in auth information
api = tweepy.API(auth)

# %% [markdown]
# # Tweet Extraction
# ### Extract JSON tweets and then store in Pandas DataFrame

# %%
# Using the API object to get tweets from timeline
# For the ID block in timeline, type in username or numeric twitter id

# Assign the keyword you'd like to query
query = 'your query here'

# public_tweets = api.user_timeline(id='pad_list', count=300)
public_tweets = api.search(q=query, lang='en', count=300)

#  Putting all individual json tweets in a list 
list_of_dicts = []

for tweet in public_tweets:
    list_of_dicts.append(tweet._json)

#  json.dumps writes python datastructure to a JSON string, to txt file
# we need JSON data in txt file to be able to work with it
with open('tweets.txt', 'w') as file:
        file.write(json.dumps(list_of_dicts, indent=4))

#  Open tweets.txt file with JSON string, flattens and extracts the
# the desired fields we want into list of dictionaries
my_list = []

with open('tweets.txt', encoding='utf-8') as json_file:
    all_data = json.load(json_file)
    for each_dictionary in all_data:     #each_dictionary is its own tweet
        tweet_id = each_dictionary['id_str']
        user_name = each_dictionary['user']['name']
        text = each_dictionary['text']
        follower_count = each_dictionary['user']['followers_count']
        favorite_count = each_dictionary['favorite_count']
        retweet_count = each_dictionary['retweet_count']
        created_at = each_dictionary['created_at']
        location = each_dictionary['user']['location']
        user_mentions = each_dictionary['entities']['user_mentions']
        coordinates = each_dictionary['coordinates']
        replied_to_tweet = each_dictionary['in_reply_to_status_id_str']
        
        my_list.append({'tweet_id': str(tweet_id),
                        'user_name': str(user_name),
                        'text': str(text),
                        'follower_count': int(follower_count),
                        'favorite_count': int(favorite_count),
                        'retweet_count': int(retweet_count),
                        'created_at': created_at,
                        'location': location,
                        'user_mentions': user_mentions,
                        'coordinates': coordinates,
                        'replied_to_tweet': replied_to_tweet})

df = pd.DataFrame(my_list, columns =
                 ['tweet_id', 'user_name', 'text', 'follower_count',
                  'favorite_count', 'retweet_count', 'created_at', 
                  'location', 'user_mentions', 'coordinates',
                  'replied_to_tweet'])

# Instantiate SentimentIntensityAnalyzer object
sid = SentimentIntensityAnalyzer()
df['sentiment_scores'] = df['text'].apply(sid.polarity_scores)

# Extract compound score and place in to new column
df['compound_scores'] = df['sentiment_scores'].apply(lambda x: x['compound'])

# Display DataFrame
df.head()
# Out:
#               tweet_id           user_name  \
# 0  1340802739375366147     Robert Dominiak
# 1  1340802667753435136                Tell
# 2  1340802667485032450              Mataya
# 3  1340802467391549441     tanglewood lion
# 4  1340802358998159361  Patrick Tomassetti
#
#                                                 text  follower_count  \
# 0  @ABC This is most likely not a practical optio...               1
# 1  and manually loads into memory an embedded pay...              18
# 2  RT @ale_sp_brazil: Malwoverview offers  techni...             133
# 3  iPhones vulnerable to hacking tool for months,...            1000
# 4  RT @YourAnonCentral: Warning: update your iOS ...              27
#
#    favorite_count  retweet_count                      created_at  \
# 0               0              0  Sun Dec 20 23:34:18 +0000 2020
# 1               0              0  Sun Dec 20 23:34:01 +0000 2020
# 2               0              5  Sun Dec 20 23:34:01 +0000 2020
# 3               0              0  Sun Dec 20 23:33:13 +0000 2020
# 4               0            155  Sun Dec 20 23:32:47 +0000 2020
#
#                   location                                      user_mentions  \
# 0  LaGrange Park, Illinois  [{'screen_name': 'ABC', 'name': 'ABC News', 'i...
# 1                                                                          []
# 2                           [{'screen_name': 'ale_sp_brazil', 'name': 'Ale...
# 3                 midlands                                                 []
# 4                           [{'screen_name': 'YourAnonCentral', 'name': 'a...
#
#   coordinates     replied_to_tweet  \
# 0        None  1340796997444509697
# 1        None  1340802336034353152
# 2        None                 None
# 3        None                 None
# 4        None                 None
#
#                                     sentiment_scores  compound_scores
# 0  {'neg': 0.148, 'neu': 0.852, 'pos': 0.0, 'comp...          -0.4497
# 1  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...           0.0000
# 2  {'neg': 0.0, 'neu': 0.844, 'pos': 0.156, 'comp...           0.4824
# 3  {'neg': 0.137, 'neu': 0.863, 'pos': 0.0, 'comp...          -0.2263
# 4  {'neg': 0.118, 'neu': 0.882, 'pos': 0.0, 'comp...          -0.3400

# %%
#  Calculate overall sentiment of the extracted tweets
df['compound_scores'].mean()
# Out:
# -0.11289900000000007

# %%
# Displaying tweets with a negative sentiment score
df[df['compound_scores'] < 0]
# Out:
#                tweet_id                  user_name  \
# 0   1340802739375366147            Robert Dominiak
# 3   1340802467391549441            tanglewood lion
# 4   1340802358998159361         Patrick Tomassetti
# 5   1340802303045988352                       n4to
# 7   1340802009537101825        Cyber Security News
# 8   1340802007783903232           Security Testing
# 10  1340801997092646913           Security Testing
# 11  1340801994315993089        Cyber Security News
# 12  1340801990692122632                 Wolfhodl Ⓥ
# 13  1340801975093518344           Security Testing
# 14  1340801971473801222        Cyber Security News
# 15  1340801952540725248       Ptrace Security GmbH
# 17  1340801849272766465             pie in our eye
# 18  1340801826761916416             pie in our eye
# 19  1340801796416155651             pie in our eye
# 22  1340801771669778433               MalTrak News
# 23  1340801768834412544               MalTrak News
# 24  1340801740451430401    Barnacules Nerdgasm 👨‍💻
# 25  1340801721900150787              Igor Akhmetov
# 26  1340801692410015745               Keepnet Labs
# 29  1340800974450008079           FelixO #EndSARS🏁
# 31  1340800909094375427                    Lurkine
# 37  1340800514464894977             james_robinson
# 39  1340800101644681216        Cyber Security Feed
# 41  1340799997361729536                Seth Goldin
# 43  1340799911764234241               Carl Mbereko
# 45  1340799738241806336              databreach911
# 47  1340799494263369730              Eve Ottenberg
# 54  1340798919710826509             Anonymous TV 🏴
# 55  1340798907140419586                 Julie Hunt
# 56  1340798877625139201                 Julie Hunt
# 57  1340798795374882819                   ovic 269
# 58  1340798689422561290        Cyber Security Feed
# 59  1340798675031867392               شيخة السلطان
# 60  1340798673584852993                       Paul
# 61  1340798637958377472  Data Governance Framework
# 67  1340798323494711297                       webb
# 68  1340798145136107522              Chris Bertsch
# 69  1340798054732062739                James Saito
# 76  1340797790029537286               ComeTogether
# 79  1340797136963776514                Ħazem Osama
# 82  1340797011826765824              •°∆  L↑∆ΠDEF.
# 83  1340797010652377089         Pierre-Paul Grassé
# 85  1340796980784738304           Security Testing
# 86  1340796978347855880        Cyber Security News
# 90  1340796898165346304                Fer/eyPanda
# 92  1340796855563804675                   LEGACY🇬🇭
# 94  1340796739696078849                 Tina Derke
# 95  1340796567608025089            Data Protection
# 97  1340796430282199040                  Ben Jones
# 99  1340796265379053568           Official O.MERCY
#
#                                                  text  follower_count  \
# 0   @ABC This is most likely not a practical optio...               1
# 3   iPhones vulnerable to hacking tool for months,...            1000
# 4   RT @YourAnonCentral: Warning: update your iOS ...              27
# 5   Many would say Stuxnet was the most devastatin...               2
# 7   RT @keepnetlabs: In #spearphishing attacks, cr...            9476
# 8   RT @keepnetlabs: In #spearphishing attacks, cr...           33768
# 10  RT @reach2ratan: 2021 Cybersecurity Prediction...           33768
# 11  RT @reach2ratan: 2021 Cybersecurity Prediction...            9476
# 12  RT @CryptoArquitect: @JimmyMcShill @notsofast ...             962
# 13  RT @ptracesecurity: Threat Roundup for Decembe...           33768
# 14  RT @ptracesecurity: Threat Roundup for Decembe...            9476
# 15  Threat Roundup for December 11 to December 18 ...           11650
# 17  RT @reach2ratan: 2021 Cybersecurity Prediction...            5072
# 18  RT @reach2ratan: NSA warns of federated login ...            5072
# 19  RT @reach2ratan: Ransomware attackers are maki...            5072
# 22  RT @CioAmaro: ISACA's State of Cybersecurity 2...            1271
# 23  RT @keepnetlabs: In #spearphishing attacks, cr...            1271
# 24  I am downloading some really shady shit off th...          119524
# 25  A hacking group is deploying a new #malware st...             104
# 26  In #spearphishing attacks, criminals can use t...             652
# 29  RT @YourAnonCentral: Warning: update your iOS ...             356
# 31  RT @YourAnonCentral: Warning: update your iOS ...              87
# 37  RT @karanortman: I recommend becoming OBSESSED...              12
# 39  RT @keepnetlabs: What risks do #phishing attac...           12821
# 41  The fundamental security problem for a compute...            1416
# 43  RT @MarkAmesExiled: Our corrupt &amp; depraved...             262
# 45  RT @Paula_Piccard: Why You Should Stop Using W...             944
# 47  RT @MarkAmesExiled: Our corrupt &amp; depraved...            3232
# 54  RT @YourAnonCentral: Warning: update your iOS ...           11130
# 55  RT @karanortman: Attackers distributed malware...            4138
# 56  RT @karanortman: I recommend becoming OBSESSED...            4138
# 57  RT @YourAnonCentral: Warning: update your iOS ...             381
# 58  RT @cybermaterial_: COURSE: E-Commerce Fraud &...           12821
# 59  RT @CioAmaro: ISACA's State of Cybersecurity 2...              42
# 60  RT @YourAnonCentral: Warning: update your iOS ...            5273
# 61  RT @Paula_Piccard: Why You Should Stop Using W...            3778
# 67  @SteIIarStardust @gamejolt Why would someone w...             606
# 68  RT @keepnetlabs: What risks do #phishing attac...             482
# 69  RT @karanortman: Attackers distributed malware...            2197
# 76  RT @jennycohn1: Remember when Trump wanted to ...            1383
# 79  RT @iblametom: New - Real world zero-click iPh...             172
# 82  RT @JordanSchachtel: Listening to Fox News and...             251
# 83  RT @YourAnonCentral: Warning: update your iOS ...             151
# 85  RT @keepnetlabs: What risks do #phishing attac...           33768
# 86  RT @keepnetlabs: What risks do #phishing attac...            9476
# 90  RT @YourAnonCentral: Warning: update your iOS ...             539
# 92  RT @CiscoUmbrella: You stopped that #Emotet tr...             322
# 94  RT @LabyrinthWeaver: Biden is inheriting an ec...             159
# 95  RT @keepnetlabs: What risks do #phishing attac...            3905
# 97  RT @Paula_Piccard: Why You Should Stop Using W...             646
# 99  RT @YourAnonCentral: Warning: update your iOS ...            1087
#
#     favorite_count  retweet_count                      created_at  \
# 0                0              0  Sun Dec 20 23:34:18 +0000 2020
# 3                0              0  Sun Dec 20 23:33:13 +0000 2020
# 4                0            155  Sun Dec 20 23:32:47 +0000 2020
# 5                0              0  Sun Dec 20 23:32:34 +0000 2020
# 7                0              3  Sun Dec 20 23:31:24 +0000 2020
# 8                0              3  Sun Dec 20 23:31:24 +0000 2020
# 10               0              7  Sun Dec 20 23:31:21 +0000 2020
# 11               0              7  Sun Dec 20 23:31:20 +0000 2020
# 12               0              1  Sun Dec 20 23:31:20 +0000 2020
# 13               0              2  Sun Dec 20 23:31:16 +0000 2020
# 14               0              2  Sun Dec 20 23:31:15 +0000 2020
# 15               0              2  Sun Dec 20 23:31:11 +0000 2020
# 17               0              7  Sun Dec 20 23:30:46 +0000 2020
# 18               0              8  Sun Dec 20 23:30:41 +0000 2020
# 19               0              5  Sun Dec 20 23:30:33 +0000 2020
# 22               0              4  Sun Dec 20 23:30:27 +0000 2020
# 23               0              3  Sun Dec 20 23:30:27 +0000 2020
# 24               9              0  Sun Dec 20 23:30:20 +0000 2020
# 25               0              0  Sun Dec 20 23:30:16 +0000 2020
# 26               0              3  Sun Dec 20 23:30:09 +0000 2020
# 29               0            155  Sun Dec 20 23:27:17 +0000 2020
# 31               0            155  Sun Dec 20 23:27:02 +0000 2020
# 37               0            617  Sun Dec 20 23:25:28 +0000 2020
# 39               0             14  Sun Dec 20 23:23:49 +0000 2020
# 41               0              0  Sun Dec 20 23:23:24 +0000 2020
# 43               0             87  Sun Dec 20 23:23:04 +0000 2020
# 45               0              6  Sun Dec 20 23:22:23 +0000 2020
# 47               0             87  Sun Dec 20 23:21:24 +0000 2020
# 54               0            155  Sun Dec 20 23:19:07 +0000 2020
# 55               0             44  Sun Dec 20 23:19:04 +0000 2020
# 56               0            617  Sun Dec 20 23:18:57 +0000 2020
# 57               0            155  Sun Dec 20 23:18:38 +0000 2020
# 58               0             10  Sun Dec 20 23:18:13 +0000 2020
# 59               0              4  Sun Dec 20 23:18:09 +0000 2020
# 60               0            155  Sun Dec 20 23:18:09 +0000 2020
# 61               0              6  Sun Dec 20 23:18:00 +0000 2020
# 67               1              0  Sun Dec 20 23:16:45 +0000 2020
# 68               0              6  Sun Dec 20 23:16:03 +0000 2020
# 69               0             44  Sun Dec 20 23:15:41 +0000 2020
# 76               0           1229  Sun Dec 20 23:14:38 +0000 2020
# 79               0             19  Sun Dec 20 23:12:02 +0000 2020
# 82               0            440  Sun Dec 20 23:11:33 +0000 2020
# 83               0            155  Sun Dec 20 23:11:32 +0000 2020
# 85               0              6  Sun Dec 20 23:11:25 +0000 2020
# 86               0              6  Sun Dec 20 23:11:25 +0000 2020
# 90               0            155  Sun Dec 20 23:11:05 +0000 2020
# 92               0             13  Sun Dec 20 23:10:55 +0000 2020
# 94               0             56  Sun Dec 20 23:10:28 +0000 2020
# 95               0              6  Sun Dec 20 23:09:47 +0000 2020
# 97               0              6  Sun Dec 20 23:09:14 +0000 2020
# 99               0            155  Sun Dec 20 23:08:35 +0000 2020
#
#                    location  \
# 0   LaGrange Park, Illinois
# 3                  midlands
# 4
# 5
# 7
# 8          Hyderabad, India
# 10         Hyderabad, India
# 11
# 12               Blockchain
# 13         Hyderabad, India
# 14
# 15         Zug, Switzerland
# 17             Alabama, USA
# 18             Alabama, USA
# 19             Alabama, USA
# 22     Dublin City, Ireland
# 23     Dublin City, Ireland
# 24              Seattle, WA
# 25           Russia, Moscow
# 26       Cambridge, England
# 29       YOUR NOTIFICATION
# 31         Grand Rapids, MI
# 37            Iowa City, IA
# 39                 Internet
# 41         Washington, D.C.
# 43       Country Australian
# 45
# 47        Silver Spring, MD
# 54                Internet
# 55           San Antonio TX
# 56           San Antonio TX
# 57        Villejuif, France
# 58                 Internet
# 59
# 60
# 61  England, United Kingdom
# 67            United States
# 68   Neither here nor there
# 69               Cyberspace
# 76         Wethepeople, USA
# 79                /dev/null
# 82            •°∆  L↑∆ΠDEF.
# 83
# 85         Hyderabad, India
# 86
# 90            Cabra, España
# 92           Ashanti, Ghana
# 94            Wilmington DE
# 95     Dublin City, Ireland
# 97                       US
# 99
#
#                                         user_mentions coordinates  \
# 0   [{'screen_name': 'ABC', 'name': 'ABC News', 'i...        None
# 3                                                  []        None
# 4   [{'screen_name': 'YourAnonCentral', 'name': 'a...        None
# 5                                                  []        None
# 7   [{'screen_name': 'keepnetlabs', 'name': 'Keepn...        None
# 8   [{'screen_name': 'keepnetlabs', 'name': 'Keepn...        None
# 10  [{'screen_name': 'reach2ratan', 'name': 'Ratan...        None
# 11  [{'screen_name': 'reach2ratan', 'name': 'Ratan...        None
# 12  [{'screen_name': 'CryptoArquitect', 'name': '฿...        None
# 13  [{'screen_name': 'ptracesecurity', 'name': 'Pt...        None
# 14  [{'screen_name': 'ptracesecurity', 'name': 'Pt...        None
# 15                                                 []        None
# 17  [{'screen_name': 'reach2ratan', 'name': 'Ratan...        None
# 18  [{'screen_name': 'reach2ratan', 'name': 'Ratan...        None
# 19  [{'screen_name': 'reach2ratan', 'name': 'Ratan...        None
# 22  [{'screen_name': 'CioAmaro', 'name': 'Mauricio...        None
# 23  [{'screen_name': 'keepnetlabs', 'name': 'Keepn...        None
# 24                                                 []        None
# 25                                                 []        None
# 26                                                 []        None
# 29  [{'screen_name': 'YourAnonCentral', 'name': 'a...        None
# 31  [{'screen_name': 'YourAnonCentral', 'name': 'a...        None
# 37  [{'screen_name': 'karanortman', 'name': 'Kara ...        None
# 39  [{'screen_name': 'keepnetlabs', 'name': 'Keepn...        None
# 41                                                 []        None
# 43  [{'screen_name': 'MarkAmesExiled', 'name': 'Ma...        None
# 45  [{'screen_name': 'Paula_Piccard', 'name': 'Pau...        None
# 47  [{'screen_name': 'MarkAmesExiled', 'name': 'Ma...        None
# 54  [{'screen_name': 'YourAnonCentral', 'name': 'a...        None
# 55  [{'screen_name': 'karanortman', 'name': 'Kara ...        None
# 56  [{'screen_name': 'karanortman', 'name': 'Kara ...        None
# 57  [{'screen_name': 'YourAnonCentral', 'name': 'a...        None
# 58  [{'screen_name': 'cybermaterial_', 'name': '✇ ...        None
# 59  [{'screen_name': 'CioAmaro', 'name': 'Mauricio...        None
# 60  [{'screen_name': 'YourAnonCentral', 'name': 'a...        None
# 61  [{'screen_name': 'Paula_Piccard', 'name': 'Pau...        None
# 67  [{'screen_name': 'SteIIarStardust', 'name': 'S...        None
# 68  [{'screen_name': 'keepnetlabs', 'name': 'Keepn...        None
# 69  [{'screen_name': 'karanortman', 'name': 'Kara ...        None
# 76  [{'screen_name': 'jennycohn1', 'name': 'Jennif...        None
# 79  [{'screen_name': 'iblametom', 'name': 'Thomas ...        None
# 82  [{'screen_name': 'JordanSchachtel', 'name': 'J...        None
# 83  [{'screen_name': 'YourAnonCentral', 'name': 'a...        None
# 85  [{'screen_name': 'keepnetlabs', 'name': 'Keepn...        None
# 86  [{'screen_name': 'keepnetlabs', 'name': 'Keepn...        None
# 90  [{'screen_name': 'YourAnonCentral', 'name': 'a...        None
# 92  [{'screen_name': 'CiscoUmbrella', 'name': 'Cis...        None
# 94  [{'screen_name': 'LabyrinthWeaver', 'name': 'E...        None
# 95  [{'screen_name': 'keepnetlabs', 'name': 'Keepn...        None
# 97  [{'screen_name': 'Paula_Piccard', 'name': 'Pau...        None
# 99  [{'screen_name': 'YourAnonCentral', 'name': 'a...        None
#
#        replied_to_tweet                                   sentiment_scores  \
# 0   1340796997444509697  {'neg': 0.148, 'neu': 0.852, 'pos': 0.0, 'comp...
# 3                  None  {'neg': 0.137, 'neu': 0.863, 'pos': 0.0, 'comp...
# 4                  None  {'neg': 0.118, 'neu': 0.882, 'pos': 0.0, 'comp...
# 5                  None  {'neg': 0.43, 'neu': 0.57, 'pos': 0.0, 'compou...
# 7                  None  {'neg': 0.304, 'neu': 0.553, 'pos': 0.143, 'co...
# 8                  None  {'neg': 0.304, 'neu': 0.553, 'pos': 0.143, 'co...
# 10                 None  {'neg': 0.178, 'neu': 0.822, 'pos': 0.0, 'comp...
# 11                 None  {'neg': 0.178, 'neu': 0.822, 'pos': 0.0, 'comp...
# 12                 None  {'neg': 0.1, 'neu': 0.9, 'pos': 0.0, 'compound...
# 13                 None  {'neg': 0.195, 'neu': 0.805, 'pos': 0.0, 'comp...
# 14                 None  {'neg': 0.195, 'neu': 0.805, 'pos': 0.0, 'comp...
# 15                 None  {'neg': 0.221, 'neu': 0.779, 'pos': 0.0, 'comp...
# 17                 None  {'neg': 0.178, 'neu': 0.822, 'pos': 0.0, 'comp...
# 18                 None  {'neg': 0.395, 'neu': 0.605, 'pos': 0.0, 'comp...
# 19                 None  {'neg': 0.474, 'neu': 0.526, 'pos': 0.0, 'comp...
# 22                 None  {'neg': 0.146, 'neu': 0.854, 'pos': 0.0, 'comp...
# 23                 None  {'neg': 0.304, 'neu': 0.553, 'pos': 0.143, 'co...
# 24                 None  {'neg': 0.162, 'neu': 0.838, 'pos': 0.0, 'comp...
# 25                 None  {'neg': 0.062, 'neu': 0.938, 'pos': 0.0, 'comp...
# 26                 None  {'neg': 0.335, 'neu': 0.508, 'pos': 0.157, 'co...
# 29                 None  {'neg': 0.118, 'neu': 0.882, 'pos': 0.0, 'comp...
# 31                 None  {'neg': 0.118, 'neu': 0.882, 'pos': 0.0, 'comp...
# 37                 None  {'neg': 0.167, 'neu': 0.755, 'pos': 0.078, 'co...
# 39                 None  {'neg': 0.278, 'neu': 0.722, 'pos': 0.0, 'comp...
# 41  1340798553162133506  {'neg': 0.128, 'neu': 0.758, 'pos': 0.114, 'co...
# 43                 None  {'neg': 0.184, 'neu': 0.816, 'pos': 0.0, 'comp...
# 45                 None  {'neg': 0.22, 'neu': 0.78, 'pos': 0.0, 'compou...
# 47                 None  {'neg': 0.184, 'neu': 0.816, 'pos': 0.0, 'comp...
# 54                 None  {'neg': 0.118, 'neu': 0.882, 'pos': 0.0, 'comp...
# 55                 None  {'neg': 0.162, 'neu': 0.702, 'pos': 0.136, 'co...
# 56                 None  {'neg': 0.167, 'neu': 0.755, 'pos': 0.078, 'co...
# 57                 None  {'neg': 0.118, 'neu': 0.882, 'pos': 0.0, 'comp...
# 58                 None  {'neg': 0.198, 'neu': 0.677, 'pos': 0.125, 'co...
# 59                 None  {'neg': 0.146, 'neu': 0.854, 'pos': 0.0, 'comp...
# 60                 None  {'neg': 0.118, 'neu': 0.882, 'pos': 0.0, 'comp...
# 61                 None  {'neg': 0.22, 'neu': 0.78, 'pos': 0.0, 'compou...
# 67  1340797005099126785  {'neg': 0.409, 'neu': 0.591, 'pos': 0.0, 'comp...
# 68                 None  {'neg': 0.278, 'neu': 0.722, 'pos': 0.0, 'comp...
# 69                 None  {'neg': 0.162, 'neu': 0.702, 'pos': 0.136, 'co...
# 76                 None  {'neg': 0.125, 'neu': 0.875, 'pos': 0.0, 'comp...
# 79                 None  {'neg': 0.112, 'neu': 0.888, 'pos': 0.0, 'comp...
# 82                 None  {'neg': 0.241, 'neu': 0.759, 'pos': 0.0, 'comp...
# 83                 None  {'neg': 0.118, 'neu': 0.882, 'pos': 0.0, 'comp...
# 85                 None  {'neg': 0.278, 'neu': 0.722, 'pos': 0.0, 'comp...
# 86                 None  {'neg': 0.278, 'neu': 0.722, 'pos': 0.0, 'comp...
# 90                 None  {'neg': 0.118, 'neu': 0.882, 'pos': 0.0, 'comp...
# 92                 None  {'neg': 0.19, 'neu': 0.739, 'pos': 0.07, 'comp...
# 94                 None  {'neg': 0.118, 'neu': 0.882, 'pos': 0.0, 'comp...
# 95                 None  {'neg': 0.278, 'neu': 0.722, 'pos': 0.0, 'comp...
# 97                 None  {'neg': 0.22, 'neu': 0.78, 'pos': 0.0, 'compou...
# 99                 None  {'neg': 0.118, 'neu': 0.882, 'pos': 0.0, 'comp...
#
#     compound_scores
# 0           -0.4497
# 3           -0.2263
# 4           -0.3400
# 5           -0.9193
# 7           -0.5423
# 8           -0.5423
# 10          -0.3818
# 11          -0.3818
# 12          -0.2732
# 13          -0.5267
# 14          -0.5267
# 15          -0.5267
# 17          -0.3818
# 18          -0.8176
# 19          -0.8689
# 22          -0.4404
# 23          -0.5423
# 24          -0.5965
# 25          -0.0516
# 26          -0.5423
# 29          -0.3400
# 31          -0.3400
# 37          -0.2539
# 39          -0.6124
# 41          -0.0772
# 43          -0.6705
# 45          -0.5423
# 47          -0.6705
# 54          -0.3400
# 55          -0.1531
# 56          -0.2539
# 57          -0.3400
# 58          -0.3400
# 59          -0.4404
# 60          -0.3400
# 61          -0.5423
# 67          -0.7650
# 68          -0.6124
# 69          -0.1531
# 76          -0.4588
# 79          -0.3400
# 82          -0.7906
# 83          -0.3400
# 85          -0.6124
# 86          -0.6124
# 90          -0.3400
# 92          -0.5267
# 94          -0.3400
# 95          -0.6124
# 97          -0.5423
# 99          -0.3400

# %% [markdown]
# # Export to Excel

# %%
df.to_excel('tweets.xlsx')
# %ls
# Out:
# Twitter Analysis Training.ipynb  tweet.xlsx
# Twitter Analysis.ipynb           tweets.txt

# %% [markdown]
# # Follower Extraction Tool

# %%
# Extracts list of all follower IDs for a certain accont, 'screen_name'

# Account, of which you'd like to see followers of:
screen_name = "marklamond"

follower_ID_List = []
for page in tweepy.Cursor(api.followers_ids, screen_name=screen_name).pages():
    follower_ID_List.extend(page)
    print(len(follower_ID_List))
    time.sleep(30)

print("You've added {} follower IDs to the follower".format(len(follower_ID_List)))
# Out:
# 41
# You've added 41 follower IDs to the follower

# %%
# Here, we take our new list of followers' IDs and use them to query Twitter's API
# for more detailed information. We then store that info in a DataFrame.

my_list = []
y = 0
z = 99


for x in range(int(len(follower_ID_List)/100+1)):
#for x in range(2):
    # Takes list of follower_ids and finds that user. 100 at a time
    followers = api.lookup_users(user_ids=follower_ID_List[y:z])
    followers = list(followers)
    y += 100
    z += 100
    for user in followers:
        follower_id = user.id_str
        name = user.name
        screen_name = user.screen_name
        description = user.description
        location = user.location
        follower_count = user.followers_count
        friends_count = user.friends_count
        favorite_count = user.favourites_count
        statuses_count = user.statuses_count
        created_at = user.created_at        
        

        my_list.append({'follower_id': str(follower_id),
                        'name': str(name),
                        'screen_name': str(screen_name),
                        'description': str(description),
                        'location': str(location),
                        'follower_count': int(follower_count),
                        'friends_count': int(friends_count),
                        'favorite_count': int(favorite_count),
                        'statuses_count': int(statuses_count),
                        'created_at': created_at})
        

df = pd.DataFrame(my_list, columns =
                 ['follower_id', 'name', 'screen_name', 'description', 
                  'location', 'follower_count', 'friends_count', 'favorite_count',
                  'statuses_count', 'created_at'])


df1 = pd.DataFrame(columns =
                 ['follower_id', 'name', 'screen_name', 'description', 
                  'location', 'follower_count', 'friends_count', 'favorite_count',
                  'statuses_count', 'created_at'])

df1.set_index('follower_id')

df1 = df1.append(df)


sid = SentimentIntensityAnalyzer()
df1['sentiment_scores'] = df1['description'].apply(sid.polarity_scores)

# Extract compound score and place in to new column
df1['compound_scores'] = df1['sentiment_scores'].apply(lambda x: x['compound'])


print("Job Finished")
# Out:
# Job Finished
